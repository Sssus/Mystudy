# %%
import mglearn
# Out:
# C:\Users\ktm\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# C:\Users\ktm\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
mglearn.plots.plot_kmeans_algorithm()

# %%
## Algorithm 
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans

# %%
## 2차원 데이터 생성
X,y=make_moons(n_samples=200,noise=0.05,random_state=0)

# %%
kmeans=KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
y_pred=kmeans.predict(X)
y_pred
# Out:
# array([0, 2, 1, 3, 2, 2, 0, 0, 0, 0, 1, 0, 2, 2, 3, 0, 1, 0, 1, 3, 2, 0,
#        1, 2, 1, 0, 2, 2, 0, 1, 0, 1, 0, 1, 1, 2, 0, 0, 3, 1, 0, 3, 1, 0,
#        2, 1, 0, 3, 0, 0, 3, 0, 2, 3, 0, 1, 1, 2, 1, 1, 0, 3, 2, 0, 0, 3,
#        1, 2, 1, 3, 0, 3, 0, 1, 0, 3, 1, 0, 1, 0, 2, 1, 0, 2, 1, 1, 0, 1,
#        0, 2, 1, 0, 2, 3, 2, 2, 2, 0, 3, 0, 2, 2, 1, 0, 3, 1, 3, 3, 2, 1,
#        3, 1, 1, 3, 0, 2, 1, 2, 0, 0, 0, 3, 1, 1, 1, 3, 0, 0, 2, 2, 0, 3,
#        3, 0, 2, 2, 0, 3, 2, 0, 0, 1, 1, 1, 3, 0, 0, 2, 1, 1, 0, 2, 0, 1,
#        0, 1, 2, 0, 1, 1, 0, 0, 1, 2, 0, 2, 1, 0, 2, 0, 1, 3, 3, 3, 0, 0,
#        2, 3, 3, 1, 2, 3, 2, 2, 2, 1, 1, 0, 3, 3, 3, 1, 0, 0, 1, 3, 2, 0,
#        1, 2])

# %%
## visualization
print(X.shape,y.shape)
# Out:
# (200, 2) (200,)

# %%
import matplotlib.pyplot as plt

# %%
col1=X[:,0]
col2=X[:,1]

# %%
plt.scatter(col1,col2,c=y_pred,cmap=mglearn.cm2,s=60)

# %%
## Clustering
from sklearn.datasets import make_blobs
X,y=make_blobs(random_state=1)

# %%
## Model Making
kmean=KMeans(n_clusters=3)
kmean
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
## Model Train
kmean.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
## Model predict
y_predict=kmean.predict(X)
y_predict
# Out:
# array([0, 2, 2, 2, 1, 1, 1, 2, 0, 0, 2, 2, 1, 0, 1, 1, 1, 0, 2, 2, 1, 2,
#        1, 0, 2, 1, 1, 0, 0, 1, 0, 0, 1, 0, 2, 1, 2, 2, 2, 1, 1, 2, 0, 2,
#        2, 1, 0, 0, 0, 0, 2, 1, 1, 1, 0, 1, 2, 2, 0, 0, 2, 1, 1, 2, 2, 1,
#        0, 1, 0, 2, 2, 2, 1, 0, 0, 2, 1, 1, 0, 2, 0, 2, 2, 1, 0, 0, 0, 0,
#        2, 0, 1, 0, 0, 2, 2, 1, 1, 0, 1, 0])

# %%
col1=X[:,0]
col2=X[:,1]

# %%
plt.scatter(col1,col2,c=y_predict,cmap=mglearn.cm3,s=60)
