# %% [markdown]
# # Data Analysis

# %% [markdown]
# 여러가지 데이터 분석에 대한 개념을 먼저 잡고 기술에 대한 부분을 들어가도록 하자.
# Overview는 개념을 잡아가면서 항목을 업데이트하자.

# %% [markdown]
# - 상관분석
# - 분산분석
# - 빈도분석
# - 평균분석
# - 동일성 검정
# - 독립성 검정
# - 정규성 검정
# - 교차성 검정
# - 변량분석
# - 단순 선형 회귀분석
# - 다중 선형 회귀분석
# - 다항 회귀분석
# - 로지스틱 회귀분석
# - 시계열 분석
# - Ridge Lasso
# - 시계열 분석
# - 머신러닝
# - 딥러닝
# - 랜덤포레스트
# - nnet
# - CNN
